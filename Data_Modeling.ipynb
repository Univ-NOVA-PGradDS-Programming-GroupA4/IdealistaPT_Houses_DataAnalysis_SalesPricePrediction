# %% [markdown]
# ##**Regressors**

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.3.0)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5

# %%
from google.colab import userdata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Modellingfrom lightgbm import LGBMClassifier
from sklearn import datasets
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV,  GridSearchCV
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings('ignore')

# %%
data_to_model = pd.read_csv('data_to_model2.csv')
target = data_to_model['price']
features = data_to_model.drop('price', axis=1)

# %% [markdown]
# ### 1 - Preparing to feed the data to our model
#
# ## Steps:
# - Correct any previous missed errors
# - Dividing the data into training and testing datasets
# - Encoding categorical data through frequency encoding, we had many options but due to concerns about increasing unnecessarily the numbers of columns and to keep things as simple as possible we chose this method
# - Finaly test various Machine Learning models to find out which one is more appropriate for this problem and doing a little parameter optimization to see if we can "squeeze" more performance out of our chosen model.

# %%
features["hasLift"] = features["hasLift"].replace('False', 0).astype(int)
features["hasLift"].value_counts()
# Out:
# hasLift
# 0    9716
# 1    7407
# Name: count, dtype: int64

# %% [markdown]
# Before encoding our categorical and numerical data we split the dataset into training and testing data and apply the transformations separately to avoid any possibility of data leakage

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

train_city_encoding = x_train['city'].value_counts() / len(x_train)
x_train['city'] = x_train['city'].map(train_city_encoding)
x_train
# Out:
#       propertyType  size  rooms  bathrooms  floor  hasLift  parkingSpace  \
# 1959          flat    95      2          1      0        0             0
# 16208         flat    75      2          2      4        0             1
# 10072       chalet   102      3          2      0        0             0
# 1740          flat    71      2          1      2        0             0
# 1957          flat   122      2          2      2        1             1
# ...            ...   ...    ...        ...    ...      ...           ...
# 11284         flat    70      3          1      3        0             0
# 11964         flat   125      2          2      2        0             0
# 5390          flat   120      4          2      0        0             0
# 860         chalet   340      5          6      0        0             0
# 15795         flat   120      3          1      5        0             0
#
#            city  house_status
# 1959   0.500292            -1
# 16208  0.500292             0
# 10072  0.202730             0
# 1740   0.500292             0
# 1957   0.500292             0
# ...         ...           ...
# 11284  0.047452             0
# 11964  0.047452             0
# 5390   0.500292             0
# 860    0.084173             0
# 15795  0.500292             0
#
# [13698 rows x 9 columns]

# %%
test_city_encoding = x_test['city'].value_counts() / len(x_test)
x_test['city'] = x_test['city'].map(test_city_encoding)
x_test
# Out:
#       propertyType  size  rooms  bathrooms  floor  hasLift  parkingSpace  \
# 6482          flat   140      3          2      0        1             1
# 13821         flat    60      1          1      4        0             0
# 2129          flat    58      1          1      2        0             0
# 11655         flat    78      2          1      7        1             0
# 13590         flat    76      3          1      2        0             0
# ...            ...   ...    ...        ...    ...      ...           ...
# 9988        chalet   486      4          4      0        0             1
# 16246         flat    72      2          1      3        0             0
# 9252          flat   165      3          2      2        0             0
# 1954          flat    67      3          2      2        0             0
# 2225          flat    53      1          2      1        0             0
#
#            city  house_status
# 6482   0.070949             0
# 13821  0.495766             0
# 2129   0.495766             0
# 11655  0.042044             0
# 13590  0.495766            -1
# ...         ...           ...
# 9988   0.216350             0
# 16246  0.495766             0
# 9252   0.216350             0
# 1954   0.495766            -1
# 2225   0.495766             0
#
# [3425 rows x 9 columns]

# %%
train_prop_encoding = x_train['propertyType'].value_counts() / len(x_train)
x_train['propertyType'] = x_train['propertyType'].map(train_prop_encoding)
x_train
# Out:
#        propertyType  size  rooms  bathrooms  floor  hasLift  parkingSpace  \
# 1959       0.764929    95      2          1      0        0             0
# 16208      0.764929    75      2          2      4        0             1
# 10072      0.180099   102      3          2      0        0             0
# 1740       0.764929    71      2          1      2        0             0
# 1957       0.764929   122      2          2      2        1             1
# ...             ...   ...    ...        ...    ...      ...           ...
# 11284      0.764929    70      3          1      3        0             0
# 11964      0.764929   125      2          2      2        0             0
# 5390       0.764929   120      4          2      0        0             0
# 860        0.180099   340      5          6      0        0             0
# 15795      0.764929   120      3          1      5        0             0
#
#            city  house_status
# 1959   0.500292            -1
# 16208  0.500292             0
# 10072  0.202730             0
# 1740   0.500292             0
# 1957   0.500292             0
# ...         ...           ...
# 11284  0.047452             0
# 11964  0.047452             0
# 5390   0.500292             0
# 860    0.084173             0
# 15795  0.500292             0
#
# [13698 rows x 9 columns]

# %%
test_prop_encoding = x_test['propertyType'].value_counts() / len(x_test)
x_test['propertyType'] = x_test['propertyType'].map(test_prop_encoding)
x_test
# Out:
#        propertyType  size  rooms  bathrooms  floor  hasLift  parkingSpace  \
# 6482       0.755036   140      3          2      0        1             1
# 13821      0.755036    60      1          1      4        0             0
# 2129       0.755036    58      1          1      2        0             0
# 11655      0.755036    78      2          1      7        1             0
# 13590      0.755036    76      3          1      2        0             0
# ...             ...   ...    ...        ...    ...      ...           ...
# 9988       0.191825   486      4          4      0        0             1
# 16246      0.755036    72      2          1      3        0             0
# 9252       0.755036   165      3          2      2        0             0
# 1954       0.755036    67      3          2      2        0             0
# 2225       0.755036    53      1          2      1        0             0
#
#            city  house_status
# 6482   0.070949             0
# 13821  0.495766             0
# 2129   0.495766             0
# 11655  0.042044             0
# 13590  0.495766            -1
# ...         ...           ...
# 9988   0.216350             0
# 16246  0.495766             0
# 9252   0.216350             0
# 1954   0.495766            -1
# 2225   0.495766             0
#
# [3425 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train[["size", "rooms", "bathrooms", "floor", "hasLift", "parkingSpace", "house_status"]] = scaler.fit_transform(x_train[["size", "rooms", "bathrooms", "floor", "hasLift", "parkingSpace", "house_status"]])
x_test[["size", "rooms", "bathrooms", "floor", "hasLift", "parkingSpace", "house_status"]] = scaler.transform(x_test[["size", "rooms", "bathrooms", "floor", "hasLift", "parkingSpace", "house_status"]])

# %%
x_train
# Out:
#        propertyType      size     rooms  bathrooms     floor   hasLift  \
# 1959       0.764929 -0.241531 -0.506375  -0.936881 -0.922653 -0.872033
# 16208      0.764929 -0.317338 -0.506375  -0.193605  0.830138 -0.872033
# 10072      0.180099 -0.214998  0.157770  -0.193605 -0.922653 -0.872033
# 1740       0.764929 -0.332500 -0.506375  -0.936881 -0.046257 -0.872033
# 1957       0.764929 -0.139190 -0.506375  -0.193605 -0.046257  1.146745
# ...             ...       ...       ...        ...       ...       ...
# 11284      0.764929 -0.336290  0.157770  -0.936881  0.391940 -0.872033
# 11964      0.764929 -0.127819 -0.506375  -0.193605 -0.046257 -0.872033
# 5390       0.764929 -0.146771  0.821914  -0.193605 -0.922653 -0.872033
# 860        0.180099  0.687114  1.486059   2.779497 -0.922653 -0.872033
# 15795      0.764929 -0.146771  0.157770  -0.936881  1.268336 -0.872033
#
#        parkingSpace      city  house_status
# 1959      -0.732234  0.500292     -2.574575
# 16208      1.365683  0.500292     -0.243982
# 10072     -0.732234  0.202730     -0.243982
# 1740      -0.732234  0.500292     -0.243982
# 1957       1.365683  0.500292     -0.243982
# ...             ...       ...           ...
# 11284     -0.732234  0.047452     -0.243982
# 11964     -0.732234  0.047452     -0.243982
# 5390      -0.732234  0.500292     -0.243982
# 860       -0.732234  0.084173     -0.243982
# 15795     -0.732234  0.500292     -0.243982
#
# [13698 rows x 9 columns]

# %% [markdown]
# To evaluate the model we use the four methods seen below: Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error and R squared. We will focus more on the last one due to it's easiness of interpretability, but there's obviously pro's and con's to each of those metrics.

# %%
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %% [markdown]
# In our brief experiment, Random Forrest Regressor emerged as the best option with a R squared score close to 0.75 meaning that our model can explain 3/4 of the variance of the data. Not bad for a start.

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Lasso": Lasso(),
    "Ridge": Ridge(),
    "K-Neighbors Regressor": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "XGBRegressor": XGBRegressor(),
    "CatBoosting Regressor": CatBoostRegressor(verbose=False),
    "AdaBoost Regressor": AdaBoostRegressor()
}
model_list = []
mae_list = []
mse_list = []
rmse_list = []
r2_list =[]

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    # Evaluate Train and Test dataset
    model_train_mae , model_train_mse, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)

    model_test_mae , model_test_mse, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    model_list.append(list(models.keys())[i])
    mae_list.append(model_test_mae)
    mse_list.append(model_test_mse)
    rmse_list.append(model_test_rmse)
    r2_list.append(model_test_r2)

pd.DataFrame(list(zip(model_list, mae_list, mse_list, r2_list)), columns=['Model Name', 'MAE_Score', 'MSE_Score', 'R2_Score']).sort_values(by=["R2_Score"],ascending=False)
# Out:
#                 Model Name      MAE_Score     MSE_Score  R2_Score
# 5  Random Forest Regressor  213811.162220  2.410630e+11  0.736330
# 7    CatBoosting Regressor  234526.704328  2.936378e+11  0.678825
# 4            Decision Tree  248660.783142  3.354132e+11  0.633132
# 3    K-Neighbors Regressor  272393.829606  3.722290e+11  0.592864
# 8       AdaBoost Regressor  352360.963223  3.871952e+11  0.576494
# 6             XGBRegressor  265846.583004  4.107892e+11  0.550687
# 0        Linear Regression  356856.074929  4.940984e+11  0.459565
# 1                    Lasso  356855.268978  4.940989e+11  0.459565
# 2                    Ridge  356824.809020  4.941005e+11  0.459563

# %% [markdown]
# Here we quickly tweak some parameters to see if we can improve our results.

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# %%
grid_search = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid, refit=True, cv=5, scoring='f1', verbose=3)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.5s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.5s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.4s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.5s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.5s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.6s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.9s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.9s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.2s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   1.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   1.3s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   1.3s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   1.3s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   2.5s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   2.5s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   2.5s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   2.5s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   2.5s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   2.5s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   2.5s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   2.5s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   2.5s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   2.5s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   3.7s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   3.7s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   2.4s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   2.4s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   2.4s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.1s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.2s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.1s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.1s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.1s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.3s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.3s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.3s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.3s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.3s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.4s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.5s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.5s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.5s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.5s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.7s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.7s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.6s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.6s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.6s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.6s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.3s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.3s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.3s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.3s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.4s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.4s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.5s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.5s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.5s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.3s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.3s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.3s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.3s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.3s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   3.2s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=300;, score=nan total time=   4.8s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.2s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   3.1s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=300;, score=nan total time=   4.7s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   3.1s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=300;, score=nan total time=   4.7s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   1.5s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.0s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.0s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.0s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.1s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   3.1s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.5s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=300;, score=nan total time=   4.6s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.2s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.2s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.2s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.2s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   2.2s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.4s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.5s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.4s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.5s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   4.4s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=nan total time=   6.7s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   1.9s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   3.8s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=300;, score=nan total time=   5.7s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   1.7s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.3s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   3.4s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.0s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.1s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=nan total time=   5.1s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.9s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.8s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   1.9s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   3.7s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.6s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=nan total time=   5.5s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   1.8s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   3.6s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=300;, score=nan total time=   5.4s

# %%
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# %%
print("Best parameters found: ", best_params)
print("Best score found: ", best_score)

# %%
tuned_rf = RandomForestRegressor(max_depth=5, max_leaf_nodes=20, n_estimators=50)
tuned_rf.fit(x_train, y_train)
tuned_y_test_pred = tuned_rf.predict(x_test)
model_test_mae , model_test_mse, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)
print({"MAE": model_test_mae , "MSE": model_test_mse, "RMSE": model_test_rmse, "R2": model_test_r2})
