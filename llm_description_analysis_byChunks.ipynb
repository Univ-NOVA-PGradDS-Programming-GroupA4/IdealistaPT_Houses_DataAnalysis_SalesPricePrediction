# %% [markdown]
# # LLM for analyzing Description content and evaluate the ad's validity

# %% [markdown]
# ## 1. Initialize notebook

# %%
#import libraries
import pandas as pd
from langchain_community.llms import Ollama
import time

# %%
#import clean dataset
df = pd.read_csv('data_clean4.csv')

# %%
#create model
#llama3 is the most advanced model to run locally
llm = Ollama(model="llama3", temperature=0.2)
#temperature 0.2 for increased accuracy and less creativity, according to the task at hand

# %% [markdown]
# ## 2. Prompt engineering

# %%
#template that will be used in all calls of the llm

PROMPT_TEMPLATE = """\
You are a good detective specialized in the housing market. You will get a text describing a house sale from a website which may be in Portuguese or Spanish.
The houses should be sold in good condition, or about to be ready to live in. However, some houses are ruins or only have the project of the house, but no building at all.
Your job is to get read the description and tell me if the house is not proper for an ad because of it not having a building or being a ruin or some condition that makes inhabitable.

Considering the following description:
----------------
{description}
----------------

Tell me if the house is not proper for an ad because of it not having a building or being a ruin or some condition that makes inhabitable, in which case respond only 'no' (not proper) or 'yes' (proper).
Do not say anything else.
"""

# %% [markdown]
# ## 3. Evaluate content of Description and get LLM's evaluation

# %%
#list to store the answers, this list will turn into a new column for the df


# Record the start time
start_time = time.time()


# Loop through the first 100 rows of the DataFrame
for j in range (17): #to save data every 1000 iterations
    lista = []
    rows = []
    print(f'Working on row {row} and the next 999.')
    
    inner_start = time.time()
    for i in range(1000): # Process each row in the current chunk
        row = j*1000+i
        if row%100 == 0:
            print(f'Working on row {row}')
        if row >= len(df): # Exit if row exceeds DataFrame length
            break  
        # Check if the 'description' field is NaN
        if pd.isna(df.iloc[row]['description']):
            answer = 'empty'
        else:
            # Format the prompt with the description
            description = df.iloc[row]['description']
            prompt = PROMPT_TEMPLATE.format(description=description)
            # Invoke the LLM with the formatted prompt
            answer = llm.invoke(prompt)
        # Append the answer to the list
        lista.append(answer)
        rows.append(row)

    #create Series and save to disk
    series = pd.Series(data=lista, index=rows)
    series.to_csv(f'series_{row}.csv') #saves name with last row from that group
    print('Saved data.')

    #time spent
    inner_end = time.time()
    inner_duration = inner_end-inner_start
    print(f'This cycle took {inner_duration:.0f} seconds')



# Record the end time
end_time = time.time()
duration = end_time - start_time
print(f"Time taken for the loop: {duration:.0f} seconds")
# Out:
# Working on row 4437 and the next 999.
# Working on row 0
# Working on row 100
# Working on row 200
# Working on row 300
# Working on row 400
# Working on row 500
# Working on row 600
# Working on row 700
# Working on row 800
# Working on row 900
# Saved data.
# This cycle took 0 seconds
# Working on row 999 and the next 999.
# Working on row 1000
# Working on row 1100
# Working on row 1200
# Working on row 1300
# Working on row 1400
# Working on row 1500
# Working on row 1600
# Working on row 1700
# Working on row 1800
# Working on row 1900
# Saved data.
# This cycle took 3 seconds
# Working on row 1999 and the next 999.
# Working on row 2000
# Working on row 2100
# Working on row 2200
# Working on row 2300
# Working on row 2400
# Working on row 2500
# Working on row 2600
# Working on row 2700
# Working on row 2800
# Working on row 2900
# Saved data.
# This cycle took 0 seconds
# Working on row 2999 and the next 999.
# Working on row 3000
# Working on row 3100
# Working on row 3200
# Working on row 3300
# Working on row 3400
# Working on row 3500
# Working on row 3600
# Working on row 3700
# Working on row 3800
# Working on row 3900
# Saved data.
# This cycle took 0 seconds
# Working on row 3999 and the next 999.
# Working on row 4000
# Working on row 4100
# Working on row 4200
# Working on row 4300
# Working on row 4400
# Working on row 4500
# Working on row 4600
# Working on row 4700
# Working on row 4800
# Working on row 4900
# Saved data.
# This cycle took 0 seconds
# Working on row 4999 and the next 999.
# Working on row 5000
# Working on row 5100
# Working on row 5200
# Working on row 5300
# Working on row 5400
# Working on row 5500
# Working on row 5600
# Working on row 5700
# Working on row 5800
# Working on row 5900
# Saved data.
# This cycle took 0 seconds
# Working on row 5999 and the next 999.
# Working on row 6000
# Working on row 6100
# Working on row 6200
# Working on row 6300
# Working on row 6400
# Working on row 6500
# Working on row 6600
# Working on row 6700
# Working on row 6800
# Working on row 6900
# Saved data.
# This cycle took 0 seconds
# Working on row 6999 and the next 999.
# Working on row 7000
# Working on row 7100
# Working on row 7200
# Working on row 7300
# Working on row 7400
# Working on row 7500
# Working on row 7600
# Working on row 7700
# Working on row 7800
# Working on row 7900
# Saved data.
# This cycle took 3 seconds
# Working on row 7999 and the next 999.
# Working on row 8000
# Working on row 8100
# Working on row 8200
# Working on row 8300
# Working on row 8400
# Working on row 8500
# Working on row 8600
# Working on row 8700
# Working on row 8800
# Working on row 8900
# Saved data.
# This cycle took 0 seconds
# Working on row 8999 and the next 999.
# Working on row 9000
# Working on row 9100
# Working on row 9200
# Working on row 9300
# Working on row 9400
# Working on row 9500
# Working on row 9600
# Working on row 9700
# Working on row 9800
# Working on row 9900
# Saved data.
# This cycle took 3 seconds
# Working on row 9999 and the next 999.
# Working on row 10000
# Working on row 10100
# Working on row 10200
# Working on row 10300
# Working on row 10400
# Working on row 10500
# Working on row 10600
# Working on row 10700
# Working on row 10800
# Working on row 10900
# Saved data.
# This cycle took 3 seconds
# Working on row 10999 and the next 999.
# Working on row 11000
# Working on row 11100
# Working on row 11200
# Working on row 11300
# Working on row 11400
# Working on row 11500
# Working on row 11600
# Working on row 11700
# Working on row 11800
# Working on row 11900
# Saved data.
# This cycle took 3 seconds
# Working on row 11999 and the next 999.
# Working on row 12000
# Working on row 12100
# Working on row 12200
# Working on row 12300
# Working on row 12400
# Working on row 12500
# Working on row 12600
# Working on row 12700
# Working on row 12800
# Working on row 12900
# Saved data.
# This cycle took 3 seconds
# Working on row 12999 and the next 999.
# Working on row 13000
# Working on row 13100
# Working on row 13200
# Working on row 13300
# Working on row 13400
# Working on row 13500
# Working on row 13600
# Working on row 13700
# Working on row 13800
# Working on row 13900
# Saved data.
# This cycle took 0 seconds
# Working on row 13999 and the next 999.
# Working on row 14000
# Working on row 14100
# Working on row 14200
# Working on row 14300
# Working on row 14400
# Working on row 14500
# Working on row 14600
# Working on row 14700
# Working on row 14800
# Working on row 14900
# Saved data.
# This cycle took 3 seconds
# Working on row 14999 and the next 999.
# Working on row 15000
# Working on row 15100
# Working on row 15200
# Working on row 15300
# Working on row 15400
# Working on row 15500
# Working on row 15600
# Working on row 15700
# Working on row 15800
# Working on row 15900
# Saved data.
# This cycle took 3 seconds
# Working on row 15999 and the next 999.
# Working on row 16000
# Working on row 16100
# Working on row 16200
# Working on row 16300
# Working on row 16400
# Working on row 16500
# Working on row 16600
# Working on row 16700
# Working on row 16800
# Working on row 16900
# Saved data.
# This cycle took 0 seconds
# Time taken for the loop: 24583 seconds

# %%
#evaluate performance
yes=lista.count('Yes')
no=lista.count('No')
percent=(yes+no)/len(lista)
print(f'number of "yes": {yes}')
print(f'number of "no": {no}')
total=yes+no
print(f'Percent of entries with description is: {total/len(lista)*100:.1f}%')
print(f'"No" percentage is: {no/(total)*100:.1f}%')
# Out:
# number of "yes": 52
# number of "no": 6
# Percent of entries with description is: 58.0%
# "No" percentage is: 10.3%

# %%
total_duration = duration/total*8500/60/60 #aprox duration of analyzing the whole dataset (in hours)
print(f'Analyzing the whole dataset would take {total_duration} hours.')
# Out:
# Analyzing the whole dataset would take 9.256667673473617 hours.

# %% [markdown]
# ## Next Steps
# - run model on the whole dataset
# - create a new column in the df with the result from the LLM, and  eclude the 'no' entries
# - re-train ML model on the new, cleaner dataset
# - re-analyze data on the new, cleaner dataset
